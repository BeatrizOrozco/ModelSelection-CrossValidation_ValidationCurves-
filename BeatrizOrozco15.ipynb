# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn.linear_model
# %matplotlib inline

# %%
data = pd.read_csv('Cars93.csv')

# %%
x = list(data['Horsepower'])
y = list(data['Price'].values.reshape(-1,1))

# %%
plt.scatter(x,y)

# %%
import sklearn.model_selection

# %%
x_train=[]
y_train=[]
for i in range(len(x)):
    x_train.append(x[:i]+x[(i+1):])
    y_train.append(y[:i]+y[(i+1):])

# %%
x_train=np.squeeze(np.split(np.array(x_train), len(x)))
y_train=np.squeeze(np.split(np.array(y_train), len(y)))

# %%
y_train[0]
# Out:
# array([33.9, 29.1, 37.7, 30. , 15.7, 20.8, 23.7, 26.3, 34.7, 40.1, 13.4,
#        11.4, 15.1, 15.9, 16.3, 16.6, 18.8, 38. , 18.4, 15.8, 29.5,  9.2,
#        11.3, 13.3, 19. , 15.6, 25.8, 12.2, 19.3,  7.4, 10.1, 11.3, 15.9,
#        14. , 19.9, 20.2, 20.9,  8.4, 12.5, 19.8, 12.1, 17.5,  8. , 10. ,
#        10. , 13.9, 47.9, 28. , 35.2, 34.3, 36.1,  8.3, 11.6, 16.5, 19.1,
#        32.5, 31.9, 61.9, 14.1, 14.9, 10.3, 26.1, 11.8, 15.7, 19.1, 21.5,
#        13.5, 16.3, 19.5, 20.7, 14.4,  9. , 11.1, 17.7, 18.5, 24.4, 28.7,
#        11.1,  8.4, 10.9, 19.5,  8.6,  9.8, 18.4, 18.2, 22.7,  9.1, 19.7,
#        20. , 23.3, 22.7, 26.7])

# %%
np.polyfit(x_train[0], y_train[0],2)
# Out:
# array([-1.90260037e-04,  2.09326293e-01, -6.10681390e+00])

# %%
coefs=[]
deg=np.arange(0,10)
for i in range(len(x_train)):
    for j in range(len(deg)):
        coefs.append(np.polyfit(x_train[i], y_train[i],j))

# %%
coefs=np.squeeze(np.split(np.array(coefs), len(x)))
coefs[1][9]
# Out:
# array([-4.99935067e-17,  7.41967939e-14, -4.73366367e-11,  1.70089974e-08,
#        -3.78885472e-06,  5.42406458e-04, -4.99344521e-02,  2.85491928e+00,
#        -9.20085519e+01,  1.27957037e+03])

# %%
coef_0=[]
coef_1=[]
coef_2=[]
coef_3=[]
coef_4=[]
coef_5=[]
coef_6=[]
coef_7=[]
coef_8=[]
coef_9=[]
for i in range(len(x_train)):
    coef_0.append(coefs[i][0])
    coef_1.append(coefs[i][1])
    coef_2.append(coefs[i][2])
    coef_3.append(coefs[i][3])
    coef_4.append(coefs[i][4])
    coef_5.append(coefs[i][5])
    coef_6.append(coefs[i][6])
    coef_7.append(coefs[i][7])
    coef_8.append(coefs[i][8])
    coef_9.append(coefs[i][9])

# %%
x=np.linspace(0,300,92)

# %%
len(coef_0)
# Out:
# 93

# %%
len(x_train)
# Out:
# 93

# %%
mse_0=[]
for j in range(len(x_train)):
    mse_0.append(((coef_0[j][0])-y_train[j])**2)

mse_1=[]
for j in range(len(x_train)):
    mse_1.append(((coef_1[j][0] + x**(coef_1[j][1]))-y_train[j])**2)

mse_2=[]
for j in range(len(x_train)):
    mse_2.append(((coef_1[j][0] + x**(coef_1[j][1])+x**(coef_1[j][2]))-y_train[j])**2)
    
for j in range(len(x_train)):
    mse_3=((coef_1[j][0] + x**(coef_1[j][1])+x**(coef_1[j][2])+x**(coef_1[j][3]))-y_train[j])**2
    
for j in range(len(x_train)):
    mse_4=(coef_1[j][0] + x**(coef_1[j][1])+x**(coef_1[j][2])+x**(coef_1[j][3])+x**(coef_1[j][4]))**2
# Out:
# C:\Users\Beatriz\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in power
#   import sys
# C:\Users\Beatriz\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in power
#   # This is added back by InteractiveShellApp.init_path()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-338-3a788cf9c503> in <module>()
#       9 mse_2=[]
#      10 for j in range(len(x_train)):
# ---> 11     mse_2.append(((coef_1[j][0] + x**(coef_1[j][1])+x**(coef_1[j][2]))-y_train[j])**2)
#      12
#      13 for j in range(len(x_train)):
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
mse_1
# Out:
# [array([          inf,  826.96358282, 1404.56998744,  888.65075294,
#          241.01387616,  425.69933753,  554.00697091,  683.33234978,
#         1193.21592852, 1595.57832117,  175.45711663,  126.49666891,
#          223.44035691,  248.01895522,  260.79659301,  270.59223878,
#          347.82648616, 1432.65793927,  333.09106451,  244.955627  ,
#          861.49892152,   81.92998335,  124.36067376,  172.97209024,
#          355.39949545,  238.76999987,  658.04119324,  145.26110943,
#          366.81978368,   52.60077717,   99.05685438,  124.385299  ,
#          248.153678  ,  191.90470085,  390.18239709,  402.12675933,
#          430.69355565,   68.11552812,  152.60316222,  386.25275738,
#          142.88282003,  301.14061658,   61.67659175,   97.09113348,
#           97.09185613,  189.16026806, 2280.4051404 ,  775.82409442,
#         1228.75829782, 1166.47366766, 1292.66884966,   66.48331363,
#          131.18849597,  267.44606135,  359.24656115, 1046.76981412,
# ...

# %%
mse_2=[]    
for j in range(len(x_train)):
    mse_2=((coef_1[j][0] + x**(coef_1[j][1])+x**(coef_1[j][2]))-y_train[j])**2
mse_3=[]    
for j in range(len(x_train)):
    mse_3=((coef_1[j][0] + x**(coef_1[j][1])+x**(coef_1[j][2])+x**(coef_1[j][3]))-y_train[j])**2
mse_4=[]    
for j in range(len(x_train)):
    mse_4=(coef_1[j][0] + x**(coef_1[j][1])+x**(coef_1[j][2])+x**(coef_1[j][3])+x**(coef_1[j][4]))**2
# Out:
# []

# %%
np.mean(mse_1[1:])
# Out:
# 466.7608764856618

# %%
mse_2=[]     
for j in range(len(x_train)):
    mse_2.append(((coef_2[j][0] + x**(coef_2[j][1])++ x**(coef_2[j][2]))-y_train[j])**2)

# %%
np.mean(mse_1)
# Out:
# inf

# %%
for i in range(len(coef_3[j]-1)):
        mse_3 = np.mean(((coef_3[j][0] + x**(coef_3[j][i]))-y_train[j][i])**2)
    for i in range(len(coef_4[j]-1)):
        mse_4 = np.mean(((coef_4[j][0] + x**(coef_4[j][i]))-y_train[j][i])**2)
    for i in range(len(coef_5[j]-1)):
        mse_5 = np.mean(((coef_5[j][0] + x**(coef_5[j][i]))-y_train[j][i])**2)    
    for i in range(len(coef_6[j]-1)):
        mse_6 = np.mean(((coef_6[j][0] + x**(coef_6[j][i]))-y_train[j][i])**2)
    for i in range(len(coef_7[j]-1)):
        mse_7 = np.mean(((coef_7[j][0] + x**(coef_7[j][i]))-y_train[j][i])**2)
    for i in range(len(coef_8[j]-1)):
        mse_8 = np.mean(((coef_8[j][0] + x**(coef_8[j][i]))-y_train[j][i])**2)
    for i in range(len(coef_9[j]-1)):
        mse_9 = np.mean(((coef_9[j][0] + x**(coef_9[j][i]))-y_train[j][i])**2)
# Out:
# inf

# %%
mse.append(mse_0,mse_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-284-99145ad58b66> in <module>()
# ----> 1 mse.append(mse_0,mse_1)
#
# TypeError: append() takes exactly one argument (2 given)

# %%
for i in range(len(coef_1[j]-1)):
        mse_1 = np.mean(((coef_1[j][0] + x**(coef_1[j][i]))-y_train[j][i])**2)
    for i in range(len(coef_2[j]-1)):
        mse_2 = np.mean(((coef_2[j][0] + x**(coef_2[j][i]))-y_train[j][i])**2)
    for i in range(len(coef_3[j]-1)):
        mse_3 = np.mean(((coef_3[j][0] + x**(coef_3[j][i]))-y_train[j][i])**2)
    for i in range(len(coef_4[j]-1)):
        mse_4 = np.mean(((coef_4[j][0] + x**(coef_4[j][i]))-y_train[j][i])**2)
    for i in range(len(coef_5[j]-1)):
        mse_5 = np.mean(((coef_5[j][0] + x**(coef_5[j][i]))-y_train[j][i])**2)    
    for i in range(len(coef_6[j]-1)):
        mse_6 = np.mean(((coef_6[j][0] + x**(coef_6[j][i]))-y_train[j][i])**2)
    for i in range(len(coef_7[j]-1)):
        mse_7 = np.mean(((coef_7[j][0] + x**(coef_7[j][i]))-y_train[j][i])**2)
    for i in range(len(coef_8[j]-1)):
        mse_8 = np.mean(((coef_8[j][0] + x**(coef_8[j][i]))-y_train[j][i])**2)
    for i in range(len(coef_9[j]-1)):
        mse_9 = np.mean(((coef_9[j][0] + x**(coef_9[j][i]))-y_train[j][i])**2)
